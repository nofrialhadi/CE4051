# %% [markdown]
# ## This is a Markdown cell
#
# Double click the cell to edit it, and enter your details below. Click the "Run" button to render it again.
#
# ### Your details
#
# Your name: Nofri Alhadi
#
# Your ID number: 23188901
#
# The details above

# %% [markdown]
# ## Below is a Python cell
#
# Enter `print("hello world")` and hit Run on the cell.

# %%
# Your code
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## Now add two numbers together
#
# Enter `1 + 1`, or whatever you feel like, and hit Run

# %%
# Your code
1 + 1
# Out:
# 2

# %% [markdown]
# ## Now assign a sum to a variable
#
# Enter `a = 1 + 1`, and hit Run

# %%
# Your code
a = 1 + 1

# %% [markdown]
# Oops, nothing on the output? Try `print(a)`

# %%
# Your code
print(a)
# Out:
# 2

# %% [markdown]
# ## That's all
#
# That's it. You don't have to submit this anywhere, you're not graded. This is just to check that your Python notebook setup is working well.

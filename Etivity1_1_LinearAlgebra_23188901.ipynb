# %% [markdown]
# ### Your details

# %% [markdown]
# Name: Nofri Alhadi

# %% [markdown]
# ID number: 23188901

# %% [markdown]
# # Task 1 - Linear Algebra

# %% [markdown]
# ## Approach
#
# **Vector**
#
# a = [a1, a2, a3]
# b = [b1, b2, b3]
#
# **Scalar multiplication of a vector**
#
# 2 * a = [(2 * a1), (2 * a2), (2 * a3)]
#
#
# **Addition (+) and subtraction (-) of two vectors**
#
# a + b = [(a1 + b1), (a2 + b2), (a3 + b3)]
# a - b = [(a1 - b1), (a2 - b2), (a3 - b3)]
#
#
# **The dot product of two vectors of length n**
#
# a . b = (a1 * b1) + (a2 * b2) + (a3 * b3)
#
#
# **The cross product, which is defined for 3D-vectors**
#
# a and b start at [0, 0, 0]
# a = [a0, a1, a2]
# b = [b0, b1, b2]
#
# c0  a0  b0
# c1  a1  b1
# c2  a2  b2
#
# c0 = a1*b2 - a2*b1
# c1 = a2*b0 - a0*b2
# c2 = a0*b1 - a1*b0

# %% [markdown]
# ## Manual Calculations
#
# (If you used manual calculations to verify your code, mention them here)

# %% [markdown]
# ## Code

# %% [markdown]
# ###a. Vector Operations

# %%
################################## Libraries ##################################
import numpy as np
from ast import Try
from numpy.core.fromnumeric import shape
from numpy.matrixlib.defmatrix import matrix

################################## Variables ##################################
# Vectors
a = [1, 2, 3]
b = [4, 3, 5]
c = [3, 5, 7, 9, 2]
x = [3, 7]
y = [2, 4, 1]

# Tuples
tuple1 = (1, 2)
tuple2 = (4, 5, 6)

# Matrice
matrx1 = [[1, 2]]
matrx2 = [[4, 5, 6], [3, 1, 2]]
matrx3 = [[3, 2, 5], [1, 9, 3]]
matrx4 = [[3, 2, 6], [7, 1, 3], [2, 9, 3]]
matrx5 = [[2, 3], [7, 5]]
matrx6 = [[1, 9], [4, 2]]

# %%
# Scalar multiplication of a vector

def scalarMult(scalar_in, vector_in):
  d = []
  for i in range(len(vector_in)):
    d.append(scalar_in * vector_in[i])
  return d

print("Vector a (", len(a),"dimensions ) =", a)
print("Vector b (", len(b),"dimensions ) =", b)
print("Vector c (", len(c),"dimensions ) =", c)

scalar_in = int(input("\nPlease enter the Scalar Value: "))
print("Vector a *",scalar_in, "=", scalarMult(scalar_in, a))
print("Vector b *",scalar_in, "=", scalarMult(scalar_in, b))
print("Vector c *",scalar_in, "=", scalarMult(scalar_in, c))

# Verification with numpy
print("\nVerification with numpy:")
print("Vector shape =", np.shape(a), np.shape(b), np.shape(c))
print("Vector multiply =", np.multiply(a, scalar_in), np.multiply(b, scalar_in), np.multiply(c, scalar_in))
# Out:
# Vector a ( 3 dimensions ) = [1, 2, 3]
# Vector b ( 3 dimensions ) = [4, 3, 5]
# Vector c ( 5 dimensions ) = [3, 5, 7, 9, 2]
#
# Please enter the Scalar Value: 3
# Vector a * 3 = [3, 6, 9]
# Vector b * 3 = [12, 9, 15]
# Vector c * 3 = [9, 15, 21, 27, 6]
#
# Verification with numpy:
# Vector shape = (3,) (3,) (5,)
# Vector multiply = [3 6 9] [12  9 15] [ 9 15 21 27  6]

# %%
# Addition (+) and subtraction (-) of two vectors. Check vectors of the same size are passed.
print("Vector a (", len(a),"dimensions ) =", a)
print("Vector b (", len(b),"dimensions ) =", b)
print("Vector c (", len(c),"dimensions ) =", c)
print("")

# Vector a + Vector b and Vector a - b
vector_add = []
vector_subtr = []
for i in range(len(a)):
  vector_add.append(a[i] + b[i])
  vector_subtr.append(a[i] - b[i])
print("Vector a + Vector b =", vector_add)
print("Vector a - Vector b =", vector_subtr)

# Vector b + Vector a and Vector b - a
vector_add = []
vector_subtr = []
for i in range(len(b)):
  vector_add.append(b[i] + a[i])
  vector_subtr.append(b[i] - a[i])
print("Vector b + Vector a =", vector_add)
print("Vector b - Vector a =", vector_subtr)

# Verification with numpy
print("\nVerification with numpy:")
try:
  print("Vector a + Vector b =", np.array(a) + np.array(b))
except Exception as e:
  print("Vector a + Vector b: Error -", e)

try:
  print("Vector a - Vector b =", np.array(a) - np.array(b))
except Exception as e:
  print("Vector a - Vector b: Error -", e)

try:
  print("Vector b + Vector a =", np.array(b) + np.array(a))
except Exception as e:
  print("Vector b + Vector a: Error -", e)

try:
  print("Vector b - Vector a =", np.array(b) - np.array(a))
except Exception as e:
  print("Vector b - Vector a: Error -", e)

try:
  print("Vector a + Vector c =", np.array(a) + np.array(c))
except Exception as e:
  print("Vector a + Vector c: Error -", e)

try:
  print("Vector a - Vector c =", np.array(a) - np.array(c))
except Exception as e:
  print("Vector a - Vector c: Error -", e)

try:
  print("Vector b + Vector c =", np.array(b) + np.array(c))
except Exception as e:
  print("Vector b + Vector c: Error -", e)

try:
  print("Vector b - Vector c =", np.array(b) - np.array(c))
except Exception as e:
  print("Vector b - Vector c: Error -", e)
# Out:
# Vector a ( 3 dimensions ) = [1, 2, 3]
# Vector b ( 3 dimensions ) = [4, 3, 5]
# Vector c ( 5 dimensions ) = [3, 5, 7, 9, 2]
#
# Vector a + Vector b = [5, 5, 8]
# Vector a - Vector b = [-3, -1, -2]
# Vector b + Vector a = [5, 5, 8]
# Vector b - Vector a = [3, 1, 2]
#
# Verification with numpy:
# Vector a + Vector b = [5 5 8]
# Vector a - Vector b = [-3 -1 -2]
# Vector b + Vector a = [5 5 8]
# Vector b - Vector a = [3 1 2]
# Vector a + Vector c: Error - operands could not be broadcast together with shapes (3,) (5,)
# Vector a - Vector c: Error - operands could not be broadcast together with shapes (3,) (5,)
# Vector b + Vector c: Error - operands could not be broadcast together with shapes (3,) (5,)
# Vector b - Vector c: Error - operands could not be broadcast together with shapes (3,) (5,)

# %%
# The dot product of two vectors of length n. Check vectors of the same size are passed.
print("Vector a (", len(a),"dimensions ) =", a)
print("Vector b (", len(b),"dimensions ) =", b)
print("Vector c (", len(c),"dimensions ) =", c)
print("")

# Vector a dot Vector b
vector_dot = 0
for i in range(len(a)):
  vector_dot += a[i] * b[i]
print("Vector a dot Vector b =", vector_dot)

# Verification with numpy
print("\nVerification with numpy:")
try:
  print("Vector a dot Vector b =", np.array(a).dot(np.array(b)))
except Exception as e:
  print("Vector a dot Vector b: Error -", e)

try:
  print("Vector b dot Vector c =", np.array(b).dot(np.array(c)))
except Exception as e:
  print("Vector b dot Vector c: Error -", e)

try:
  print("Vector c dot Vector a =", np.array(c).dot(np.array(a)))
except Exception as e:
  print("Vector c dot Vector a: Error -", e)
# Out:
# Vector a ( 3 dimensions ) = [1, 2, 3]
# Vector b ( 3 dimensions ) = [4, 3, 5]
# Vector c ( 5 dimensions ) = [3, 5, 7, 9, 2]
#
# Vector a dot Vector b = 25
#
# Verification with numpy:
# Vector a dot Vector b = 25
# Vector b dot Vector c: Error - shapes (3,) and (5,) not aligned: 3 (dim 0) != 5 (dim 0)
# Vector c dot Vector a: Error - shapes (5,) and (3,) not aligned: 5 (dim 0) != 3 (dim 0)

# %%
# The cross product, which is defined for 3D-vectors. Check vectors of the correct size are passed.
print("Vector a (", len(a),"dimensions ) =", a)
print("Vector b (", len(b),"dimensions ) =", b)
print("Vector c (", len(c),"dimensions ) =", c)
print("Vector x (", len(x),"dimensions ) =", x)
print("Vector y (", len(y),"dimensions ) =", y)
print("")

# Cross product 3D Vector
#c0 = a1*b2 - a2*b1
#c1 = a2*b0 - a0*b2
#c2 = a0*b1 - a1*b0
cross_axb = []
cross_axb.append((a[1] * b[2]) - (a[2] * b[1])) # c0
cross_axb.append((a[2] * b[0]) - (a[0] * b[2])) # c1
cross_axb.append((a[0] * b[1]) - (a[1] * b[0])) # c2
print("Cross product vector a and b =", cross_axb)

# Verification with numpy
print("\nVerification with numpy:")
print("3D and 3D - Vector Cross Product Vector a and Vector b =", np.cross(a, b))
print("2D and 3D - Vector Cross Product Vector x and Vector y =", np.cross(x, y))
# Out:
# Vector a ( 3 dimensions ) = [1, 2, 3]
# Vector b ( 3 dimensions ) = [4, 3, 5]
# Vector c ( 5 dimensions ) = [3, 5, 7, 9, 2]
# Vector x ( 2 dimensions ) = [3, 7]
# Vector y ( 3 dimensions ) = [2, 4, 1]
#
# Cross product vector a and b = [1, 7, -5]
#
# Verification with numpy:
# 3D and 3D - Vector Cross Product Vector a and Vector b = [ 1  7 -5]
# 2D and 3D - Vector Cross Product Vector x and Vector y = [ 7 -3 -2]

# %% [markdown]
# ###b. Matrix Operation

# %%
# Calculate and return the size of a matrix as a 2-dimensional tuple
print("Tuple 1 (", len(tuple1),"dimensions ) =", tuple1)
print("Tuple 2 (", len(tuple2),"dimensions ) =", tuple2)

# Verification with numpy
print("\nVerification with numpy:")
print("Tuple 1 and Tuple 2 type: ", type(tuple1), type(tuple2))
print("Tuple 1 and Tuple 2 Dimension: ", np.shape(tuple1), np.shape(tuple2))
# Out:
# Tuple 1 ( 2 dimensions ) = (1, 2)
# Tuple 2 ( 3 dimensions ) = (4, 5, 6)
#
# Verification with numpy:
# Tuple 1 and Tuple 2 type:  <class 'tuple'> <class 'tuple'>
# Tuple 1 and Tuple 2 Dimension:  (2,) (3,)

# %%
# Sum/subtract the matrix with another matrix of suitable size.
# Print a suitable error message if incorrect matrix sizes are passed.

print("Matrix 1 (", len(matrx1),"dimensions,", shape(matrx1), "Size ) =", matrx1)
print("Matrix 2 (", len(matrx2),"dimensions,", shape(matrx2), "Size ) =", matrx2)
print("Matrix 3 (", len(matrx3),"dimensions,", shape(matrx3), "Size ) =", matrx3)
print("")

# Matrix 2 + Matrix 3 and Matrix 2 - Martrix 3
# Check the matrice shape
if shape(matrx2) == shape(matrx3):
  matrix_add = [[0, 0, 0], [0, 0, 0]]
  matrix_subtr = [[0, 0, 0], [0, 0, 0]]
  for i in range(len(matrx2)):
    for j in range(len(matrx2[i])):
      matrix_add[i][j] = matrx2[i][j] + matrx3[i][j]
      matrix_subtr[i][j] = matrx2[i][j] - matrx3[i][j]
  print("Matrix 2 + Matrix 3 =", matrix_add)
  print("Matrix 2 - Matrix 3 =", matrix_subtr)
else:
  print("Error: Matrix is not have same size!")

# Verification with numpy
print("\nVerification with numpy:")
print("Matrix 1, 2 and 3 Type: ", type(matrx1), type(matrx2), type(matrx3))
print("Matrix 1, 2 and 3 Size: ", np.shape(matrx1), np.shape(matrx2), np.shape(matrx3))

try:
  print("Matrix 1 + Matrix 2 =", np.array(matrx1) + np.array(matrx2))
except Exception as e:
  print("Matrix 1 + Matrix 2 = Error -", e)

try:
  print("Matrix 2 + Matrix 3 =", np.array(matrx2) + np.array(matrx3))
except Exception as e:
  print("Matrix 2 + Matrix 3 = Error -", e)

try:
  print("Matrix 1 - Matrix 2 =", np.array(matrx1) - np.array(matrx2))
except Exception as e:
  print("Matrix 1 - Matrix 2 = Error -", e)

try:
  print("Matrix 2 - Matrix 3 =", np.array(matrx2) - np.array(matrx3))
except Exception as e:
  print("Matrix 2 - Matrix 3 = Error -", e)
# Out:
# Matrix 1 ( 1 dimensions, (1, 2) Size ) = [[1, 2]]
# Matrix 2 ( 2 dimensions, (2, 3) Size ) = [[4, 5, 6], [3, 1, 2]]
# Matrix 3 ( 2 dimensions, (2, 3) Size ) = [[3, 2, 5], [1, 9, 3]]
#
# Matrix 2 + Matrix 3 = [[7, 7, 11], [4, 10, 5]]
# Matrix 2 - Matrix 3 = [[1, 3, 1], [2, -8, -1]]
#
# Verification with numpy:
# Matrix 1, 2 and 3 Type:  <class 'list'> <class 'list'> <class 'list'>
# Matrix 1, 2 and 3 Size:  (1, 2) (2, 3) (2, 3)
# Matrix 1 + Matrix 2 = Error - operands could not be broadcast together with shapes (1,2) (2,3)
# Matrix 2 + Matrix 3 = [[ 7  7 11]
#  [ 4 10  5]]
# Matrix 1 - Matrix 2 = Error - operands could not be broadcast together with shapes (1,2) (2,3)
# Matrix 2 - Matrix 3 = [[ 1  3  1]
#  [ 2 -8 -1]]

# %%
# Multiply the matrix with a vector of suitable size.
# Print a suitable error message if incorrect matrix/vector sizes are passed.

print("Vector a (", len(a),"dimensions,", shape(a), "Size ) =", a)
print("Vector b (", len(b),"dimensions,", shape(b), "Size ) =", b)
print("Vector c (", len(c),"dimensions,", shape(c), "Size ) =", c)
print("Matrix 1 (", len(matrx1),"dimensions,", shape(matrx1), "Size ) =", matrx1)
print("Matrix 2 (", len(matrx2),"dimensions,", shape(matrx2), "Size ) =", matrx2)
print("Matrix 3 (", len(matrx3),"dimensions,", shape(matrx3), "Size ) =", matrx3)
print("")

# Multiply Matrix 1 with Vector a
# Check Matrix 1 and Vector a size
print("Multiply Matrix 1 with Vector a:")
if shape(matrx1)[1] == shape(a)[0]:
  matrix_multpy = [[0, 0, 0], [0, 0, 0]]
  for i in range(len(matrx1)):
    for j in range(len(matrx1[i])):
      matrix_multpy[i][j] = matrx1[i][j] * a[j]
  print(matrix_multpy)
else:
  print("Error: Matrix 1 column and Vector a row is not in the same size!")

# Multiply Matrix 2 with Vector a
# Check Matrix 2 and Vector a
print("\nMultiply Matrix 2 with Vector a:")
if shape(matrx2)[1] == shape(a)[0]:
  matrix_multpy = [[0, 0, 0], [0, 0, 0]]
  for i in range(len(matrx2)):
    for j in range(len(matrx2[i])):
      matrix_multpy[i][j] = matrx2[i][j] * a[j]
  print(matrix_multpy)
else:
  print("Error: Matrix 2 column and Vector a row is not in the same size!")

# Verification with numpy
print("\nVerification with numpy:")

try:
  print("Multiply Matrix 1 with Vector a =", np.multiply(matrx1, a))
except Exception as e:
  print("Multiply Matrix 1 with Vector a = Error -", e)

try:
  print("Multiply Matrix 2 with Vector a =", np.multiply(matrx2, a))
except Exception as e:
  print("Multiply Matrix 2 with Vector a = Error -", e)
# Out:
# Vector a ( 3 dimensions, (3,) Size ) = [1, 2, 3]
# Vector b ( 3 dimensions, (3,) Size ) = [4, 3, 5]
# Vector c ( 5 dimensions, (5,) Size ) = [3, 5, 7, 9, 2]
# Matrix 1 ( 1 dimensions, (1, 2) Size ) = [[1, 2]]
# Matrix 2 ( 2 dimensions, (2, 3) Size ) = [[4, 5, 6], [3, 1, 2]]
# Matrix 3 ( 2 dimensions, (2, 3) Size ) = [[3, 2, 5], [1, 9, 3]]
#
# Multiply Matrix 1 with Vector a:
# Error: Matrix 1 column and Vector a row is not in the same size!
#
# Multiply Matrix 2 with Vector a:
# [[4, 10, 18], [3, 2, 6]]
#
# Verification with numpy:
# Multiply Matrix 1 with Vector a = Error - operands could not be broadcast together with shapes (1,2) (3,)
# Multiply Matrix 2 with Vector a = [[ 4 10 18]
#  [ 3  2  6]]

# %%
# Multiply the matrix with a matrix of suitable size.
# Print a suitable error message if incorrect matrix sizes are passed.

print("Matrix 1 (", len(matrx1),"dimensions,", shape(matrx1), "Size ) =", matrx1)
print("Matrix 2 (", len(matrx2),"dimensions,", shape(matrx2), "Size ) =", matrx2)
print("Matrix 3 (", len(matrx3),"dimensions,", shape(matrx3), "Size ) =", matrx3)
print("Matrix 4 (", len(matrx4),"dimensions,", shape(matrx4), "Size ) =", matrx4)
print("")

# Multiply Matrix 1 with Matrix 2
# Check Matrix 1 and Matrix 2 shape
print("Multiply Matrix 1 with Matrix 2:")
if shape(matrx1) == shape(matrx2):
  matrix_multpy = [[0, 0, 0], [0, 0, 0]]
  for i in range(len(matrx1)):
    for j in range(len(matrx1[i])):
      matrix_multpy[i][j] = matrx1[i][j] * matrx2[i][j]
  print(matrix_multpy)
else:
  print("Error: Matrix 1 shape is not same with Matrix 2 shape!")

# Multiply Matrix 2 with Matrix 3
# Check Matrix 2 and Matrix 3 shape
print("\nMultiply Matrix 2 with Matrix 3:")
if shape(matrx2) == shape(matrx3):
  matrix_multpy = [[0, 0, 0], [0, 0, 0]]
  for i in range(len(matrx2)):
    for j in range(len(matrx2[i])):
      matrix_multpy[i][j] = matrx2[i][j] * matrx3[i][j]
  print(matrix_multpy)
else:
  print("Error: Matrix 2 shape is not same with Matrix 3 shape!")

# Verification with numpy
print("\nVerification with numpy:")

try:
  print("Multiply Matrix 1 with Matrix 2 =", np.multiply(matrx1, matrx2))
except Exception as e:
  print("Multiply Matrix 1 with Matrix 2 = Error -", e)

try:
  print("Multiply Matrix 2 with Matrix 3 =", np.multiply(matrx2, matrx3))
except Exception as e:
  print("Multiply Matrix 2 with Matrix 3 = Error -", e)
# Out:
# Matrix 1 ( 1 dimensions, (1, 2) Size ) = [[1, 2]]
# Matrix 2 ( 2 dimensions, (2, 3) Size ) = [[4, 5, 6], [3, 1, 2]]
# Matrix 3 ( 2 dimensions, (2, 3) Size ) = [[3, 2, 5], [1, 9, 3]]
# Matrix 4 ( 3 dimensions, (3, 3) Size ) = [[3, 2, 6], [7, 1, 3], [2, 9, 3]]
#
# Multiply Matrix 1 with Matrix 2:
# Error: Matrix 1 shape is not same with Matrix 2 shape!
#
# Multiply Matrix 2 with Matrix 3:
# [[12, 10, 30], [3, 9, 6]]
#
# Verification with numpy:
# Multiply Matrix 1 with Matrix 2 = Error - operands could not be broadcast together with shapes (1,2) (2,3)
# Multiply Matrix 2 with Matrix 3 = [[12 10 30]
#  [ 3  9  6]]

# %%
# Calculate the determinant of a 2x2 matrix.
# For any other matrix this function should print a suitable error message.

print("Matrix 2 (", len(matrx2),"dimensions,", shape(matrx2), "Size ) =", matrx2)
print("Matrix 5 (", len(matrx5),"dimensions,", shape(matrx5), "Size ) =", matrx5)
print("Matrix 6 (", len(matrx6),"dimensions,", shape(matrx6), "Size ) =", matrx6)

# Check Matrix 2 shape
print("\nDeterminant Matrix 2:")
if shape(matrx2) == (2, 2):
  matrix_det = (matrx2[0][0] * matrx2[1][1]) - (matrx2[1][0] * matrx2[0][1])
  print(matrix_det)
else:
  print("Error: Matrix 2 shape is not 2x2!")

# ([0][0] x [1][1]) - ([1][0] x [0][1])
# Check Matrix 5 shape
print("\nDeterminant Matrix 5:")
if shape(matrx5) == (2, 2):
  matrix_det = (matrx5[0][0] * matrx5[1][1]) - (matrx5[1][0] * matrx5[0][1])
  print(matrix_det)
else:
  print("Error: Matrix 5 shape is not 2x2!")

# Check Matrix 6 shape
print("\nDeterminant Matrix 6:")
if shape(matrx6) == (2, 2):
  matrix_det = (matrx6[0][0] * matrx6[1][1]) - (matrx6[1][0] * matrx6[0][1])
  print(matrix_det)
else:
  print("Error: Matrix 6 shape is not 2x2!")

# Verification with numpy
print("\nVerification with numpy:")
print("Matrix 2, 5, and 6 Type: ", type(matrx2), type(matrx5), type(matrx6))
print("Matrix 2, 5 and 6 Size: ", np.shape(matrx2), np.shape(matrx5), np.shape(matrx6))

try:
  print("Determinant Matrix 2 =", np.linalg.det(matrx2))
except Exception as e:
  print("Determinant Matrix 2 = Error -", e)

try:
  print("Determinant Matrix 5 =", int(np.linalg.det(matrx5)))
except Exception as e:
  print("Determinant Matrix 5 = Error -", e)

try:
  print("Determinant Matrix 6 =", int(np.linalg.det(matrx6)))
except Exception as e:
  print("Determinant Matrix 6 = Error -", e)
# Out:
# Matrix 2 ( 2 dimensions, (2, 3) Size ) = [[4, 5, 6], [3, 1, 2]]
# Matrix 5 ( 2 dimensions, (2, 2) Size ) = [[2, 3], [7, 5]]
# Matrix 6 ( 2 dimensions, (2, 2) Size ) = [[1, 9], [4, 2]]
#
# Determinant Matrix 2:
# Error: Matrix 2 shape is not 2x2!
#
# Determinant Matrix 5:
# -11
#
# Determinant Matrix 6:
# -34
#
# Verification with numpy:
# Matrix 2, 5, and 6 Type:  <class 'list'> <class 'list'> <class 'list'>
# Matrix 2, 5 and 6 Size:  (2, 3) (2, 2) (2, 2)
# Determinant Matrix 2 = Error - Last 2 dimensions of the array must be square
# Determinant Matrix 5 = -11
# Determinant Matrix 6 = -34

# %%
# Calculate the inverse of a 2x2 matrix.
# For any other matrix this function should print a suitable error message.
# An error message should also be raised if the matrix is non-invertible.
print("Matrix 2 (", len(matrx2),"dimensions,", shape(matrx2), "Size ) =", matrx2)
print("Matrix 5 (", len(matrx5),"dimensions,", shape(matrx5), "Size ) =", matrx5)
print("Matrix 6 (", len(matrx6),"dimensions,", shape(matrx6), "Size ) =", matrx6)
print("")

def matrixInv(matrix_in):
  # Check Matrix can be Inverse: number of row = number of column
  if shape(matrix_in)[0] == shape(matrix_in)[1]:
    # Check Matrix shape
    if shape(matrix_in) == (2, 2):
      matrix_swap = [[0, 0], [0, 0]]
      matrix_swap[0][0] = matrix_in[1][1]
      matrix_swap[0][1] = matrix_in[0][1] * -1
      matrix_swap[1][0] = matrix_in[1][0] * -1
      matrix_swap[1][1] = matrix_in[0][0]

      # calculate determinant matrix
      matrix_det = (matrix_in[0][0] * matrix_in[1][1]) - (matrix_in[1][0] * matrix_in[0][1])

      # divide matrix with determinant
      matrix_result = [[0, 0], [0, 0]]
      for i in range(len(matrix_swap)):
        for j in range(len(matrix_swap[i])):
          matrix_result[i][j] = matrix_swap[i][j] / matrix_det
      return matrix_result
    else:
      return "Error: Matrix shape is not 2x2!"
  else:
    return "Error: Matrix cannot be Inverse!. The number of row not same with the coulumn"

print("Inverse Matrix 2 =", matrixInv(matrx2))
print("Inverse Matrix 5 =", matrixInv(matrx5))
print("Inverse Matrix 6 =", matrixInv(matrx6))

# Verification with numpy
print("\nVerification with numpy:")
try:
  print("Inverse Matrix 2 =", np.linalg.inv(matrx2))
except Exception as e:
  print("Inverse Matrix 2 = Error -", e)
try:
  print("Inverse Matrix 5 =", np.linalg.inv(matrx5))
except Exception as e:
  print("Inverse Matrix 5 = Error -", e)
try:
  print("Inverse Matrix 6 =", np.linalg.inv(matrx6))
except Exception as e:
  print("Inverse Matrix 6 = Error -", e)
# Out:
# Matrix 2 ( 2 dimensions, (2, 3) Size ) = [[4, 5, 6], [3, 1, 2]]
# Matrix 5 ( 2 dimensions, (2, 2) Size ) = [[2, 3], [7, 5]]
# Matrix 6 ( 2 dimensions, (2, 2) Size ) = [[1, 9], [4, 2]]
#
# Inverse Matrix 2 = Error: Matrix cannot be Inverse!. The number of row not same with the coulumn
# Inverse Matrix 5 = [[-0.45454545454545453, 0.2727272727272727], [0.6363636363636364, -0.18181818181818182]]
# Inverse Matrix 6 = [[-0.058823529411764705, 0.2647058823529412], [0.11764705882352941, -0.029411764705882353]]
#
# Verification with numpy:
# Inverse Matrix 2 = Error - Last 2 dimensions of the array must be square
# Inverse Matrix 5 = [[-0.45454545  0.27272727]
#  [ 0.63636364 -0.18181818]]
# Inverse Matrix 6 = [[-0.05882353  0.26470588]
#  [ 0.11764706 -0.02941176]]

# %% [markdown]
# ## Discussion
#
# Provide any discussion elements
